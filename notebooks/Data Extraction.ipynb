# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
from tqdm import tqdm
import re

import datetime, time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#connect to Spotify Web API
client_id = os.environ.get('CLIENT_ID')
client_secret = os.environ.get('CLIENT_SECRET')
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,
                                        client_secret=client_secret)
sp = spotipy.client.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Load the raw_data from the repo
dataPath = 'playlist_raw_data.csv'
df = pd.read_csv(dataPath)
df.head()
# Out:
#    Unnamed: 0  pos artist_name                             track_uri  \
# 0           0    0   AronChupa  spotify:track:66U0ASk1VHZsqIkpMjKX3B
# 1           1    1   AronChupa  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 2           2    2       Lorde  spotify:track:0GZoB8h0kqXn7XFm4Sj06k
# 3           3    3       Lorde  spotify:track:35kahykNu00FPysz3C2euR
# 4           4    4       Lorde  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1
#
#                               artist_uri  \
# 0  spotify:artist:5vCOdeiQt9LyzdI87kt5Sh
# 1  spotify:artist:5vCOdeiQt9LyzdI87kt5Sh
# 2  spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# 3  spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# 4  spotify:artist:163tK9Wjr9P9DmM0AVK7lm
#
#                                           track_name  \
# 0                                       Little Swing
# 1                                   I'm an Albatraoz
# 2  Yellow Flicker Beat - From The Hunger Games: M...
# 3                                  White Teeth Teens
# 4                                               Team
#
#                               album_uri  duration_ms           album_name  \
# 0  spotify:album:4S5MLjwRSi0NJ5nikflYnZ       163809         Little Swing
# 1  spotify:album:1qHVYbxQ6IS8YRviorKDJI       166848     I'm an Albatraoz
# 2  spotify:album:4UEPxQx0cTcYNsE0n32MHV       232506  Yellow Flicker Beat
# 3  spotify:album:0rmhjUgoVa17LZuS8xWQ3v       216600         Pure Heroine
# 4  spotify:album:0rmhjUgoVa17LZuS8xWQ3v       193058         Pure Heroine
#
#     name
# 0  Party
# 1  Party
# 2  Party
# 3  Party
# 4  Party

# %%
#Edit the track-uris to a more usable format
df["track_uri"] = df["track_uri"].apply(lambda x: re.findall(r'\w+$', x)[0])
df["track_uri"]
# Out:
# 0         66U0ASk1VHZsqIkpMjKX3B
# 1         5MhsZlmKJG6X5kTHkdwC4B
# 2         0GZoB8h0kqXn7XFm4Sj06k
# 3         35kahykNu00FPysz3C2euR
# 4         3G6hD9B2ZHOsgf4WfNu7X1
#                    ...
# 280995    38griAVM808crjbFp9gcPD
# 280996    1JClFT74TYSXlzpagbmj0S
# 280997    4InLm5a9Qtkru6YxEjM4Qc
# 280998    4hdog9vyyqG9pcppG2Izek
# 280999    0NiXXAI876aGImAd6rTj8w
# Name: track_uri, Length: 281000, dtype: object

# %%
first_half = df["track_uri"].unique()[:500]

# %%
first_half
# Out:
# array(['66U0ASk1VHZsqIkpMjKX3B', '5MhsZlmKJG6X5kTHkdwC4B',
#        '0GZoB8h0kqXn7XFm4Sj06k', '35kahykNu00FPysz3C2euR',
#        '3G6hD9B2ZHOsgf4WfNu7X1', '6WQLkih8nE0JdUCEyLaGnQ',
#        '37sINbJZcFdHFAsVNsPq1i', '0yhPEz5KxlDwckGJaMlZqM',
#        '5j9iuo3tMmQIfnEEQOOjxh', '4eLSCSELtKxZwXnFbNLXT5',
#        '4PvD06Pmbm2rHG2JjSlElF', '57nNNkgk768QVXq3uHxu5e',
#        '3y8AEUef1AVfr0npU5UOa9', '5jJ69cMDMC0aeWPjZo6VP2',
#        '02b5L9jExmkRTdUTqXFzmR', '6fKEplI9iN0JMHsRGQESaT',
#        '3ebXMykcMXOcLeJ9xZ17XH', '1J9KJgXKFRqKGIzmJ7GjS3',
#        '6aBYg6Npa47VAqtEsLsUdz', '0dA2Mk56wEzDgegdC6R17g',
#        '3ik1fFvzdgmVuiob8t8NlG', '05BJQUM4bATKGFheqrC6CW',
#        '0rfGRC3ng0dxu0xZ3f1bWc', '1azvKxDb5Vkph2KR7aq1Cx',
#        '1Gsv8f8KmowkF5BnfMIGKy', '3KYiA4vq6RPO1dE2XROXd8',
#        '252pAlbltOjOcUux4dRtjp', '1ynmMEK1fkyiZ6Z6F3ThEt',
#        '7vIyudiO2Tr9hZ2yzfwQmx', '12yHvSYFXI7PGzNecUvIDu',
#        '6koWevx9MqN6efQ6qreIbm', '2F46y5zSlBKOqco0k8xQAM',
#        '00YnfZzpODxlE6nNwfPCbv', '3PiyMOuCTB4Rc624hRr2rC',
#        '6IE47jpPeatF2Iay7GZtEc', '6BOtDFg6GJm0rPUDuNmx57',
#        '6F609ICg9Spjrw1epsAnpa', '14WWzenpaEgQZlqPq2nk4v',
#        '1xznGGDReH1oQq0xzbwXa3', '1vxw6aYJls2oq3gW0DujAo',
#        '4tCtwWceOPWzenK2HAIJSb', '2ZyuwVvV6Z3XJaXIFbspeE',
#        '7yHEDfrJNd0zWOfXwydNH0', '3tRFqxTYOjeTmCiVaGDCsq',
#        '0wz1LjDb9ZNEYwOmDJ3Q4b', '1AJ5F0FMTC3yFU3ocjy1gE',
#        '75WMOzv7195ziyx0qEw1yE', '62fX8EW16l8St2yL8rMer9',
#        '6RrXd9Hph4hYR4bf3dbM6H', '31kTKEPu5PPTTODydIYai0',
#        '54i6YAQkZImwWjmzPrQeqd', '1UqhkbzB1kuFwt2iy4h29Q',
#        '03f7xZmt2wHCIDJBFPK8G4', '3ASt4jBSatnN4RGMlym74h',
#        '5bcTCxgc7xVfSaMV3RuVke', '1wjzFQodRWrPcQ0AnYnvQ9',
#        '7F9vK8hNFMml4GtHsaXui6', '2ekn2ttSfGqwhhate0LSR0',
#        '6EpRaXYhGOB3fj4V2uDkMJ', '0QXaOq4DrPkX7cJsXhERrE',
#        '3YU9X8ryOR20beT7wOlDIJ', '5MxNLUsfh7uzROypsoO5qe',
#        '2Pr1nZpt8A8WP7QYpyq6L3', '5xS9hkTGfxqXyxX6wWWTt4',
#        '38YgZVHPWOWsKrsCXz6JyP', '71eRCfoq3g4qeLNcR75Hig',
#        '6MDTpYxPFL0wtFd0pjfKws', '3X3mfRMRaPJRiIMDMQtSkd',
#        '6vECYJHxYmm3Ydt3fF01pE', '2OUCEz0B8chI3FcqloinyN',
#        '6TlJFqjUFZWqIxUPrEbhA9', '3GdvlmQ8GgfFokp1hpdRJ2',
#        '5mMbZffWy78SCQ0wlKKVot', '6c1cQOxDKZhnfu19rclv6G',
#        '0rULKUSGyvvGoAbZ1ySRPt', '7i75KH4bMsIVeC5ts8EodH',
#        '2Z3ZqLsK5YxY756378DOEM', '3RzUkUattGuBLwpb8QgiOf',
#        '1yEVIffZb0jAFoKvDnspFx', '28Ct4qwkQXY2W5yyNCLuVI',
#        '5EhzE6HJaCcLFrf5rPqvpk', '5Jhvo7ePEJJYoExxQK8MWs',
#        '1hCswNajdTPRtuggsGtpCX', '7I7y9nOpA7CvJuCzjgQrsf',
#        '5eT0hMWKFU9CYFv73f96in', '2TThaSDmqSwitNHL20NexA',
#        '2XW4AAjfBQTzp7Oe1tU702', '0Z9TbLIhMAXa8BSOiY6um6',
#        '7tmtOEDxPN7CWaQWBsG1DY', '6cREm4bV7V79Yxdilx9HDo',
#        '0t829spDK7VWpDoJ3Bi8ol', '7129iqBafaphfc3WPCGC0L',
#        '28daTa4Nga2dX0p7EXcRlL', '5YqpHuXpFjDVZ7tY1ClFll',
#        '6b2oQwSGFkzsMtQruIWm2p', '5ghIJDpPoe3CfHMGu71E6T',
#        '7fURZRPkB2S70sYR1naKTK', '0uppYCG86ajpV2hSR3dJJ0',
#        '5nkYHBWXu7KCgcdwP6jcB1', '1zWZvrk13cL8Sl3VLeG57F',
#        '5kNe7PE09d6Kvw5pAsx23n', '6GsAD8PgHxmEuIPTG8GP3M',
#        '6Knv6wdA0luoMUuuoYi2i1', '0i5el041vd6nxrGEU8QRxy',
#        '37f4ITSlgPX81ad2EvmVQr', '4LfkoDOt4mhrbo8Ndk37sQ',
#        '74Xdx4ezYQQlg8wKswq25T', '32FX4D4eT8LFP07QvlhSn8',
#        '2BaXRCVgn621xHOGoFSuW5', '5CtI0qwDJkDQGwXD1H1cLb',
#        '3DXncPQOG4VBw3QHh3S817', '7qiZfU4dY1lWllzX7mPBI3',
#        '6gBFPUFcJLzWGx4lenP6h2', '4Q3N4Ct4zCuIHuZ65E3BD4',
#        '73cAKC1NbxHuFPcQ4slGtl', '75Q69chmd8CEZbVsA4CDMm',
#        '52HjbwSaC6fhChoKGWohWA', '5Z3GHaZ6ec9bsiI5BenrbY',
#        '6t2eIONH4Sax3R21QWiKNp', '5SsR3wtCOafDmZgvIdRhSm',
#        '3LHWJ7C6P8fGzpdoiuoI3A', '31G9RaSaDOI2NWcpnIp734',
#        '722tgOgdIbNe3BEyLnejw4', '2LvRR121MWFmmEGkuV2vQP',
#        '1Ser4X0TKttOvo8bgdytTP', '60xaS8mYBKUW4VQQ666N0T',
#        '60APt5N2NRaKWf5xzJdzyC', '7yMhyRmQGv6mSD6SkfhPeF',
#        '7M2cKcvCnflzp9WcxGjlbm', '6fAyRZ0GHuuvSOEIOwi58N',
#        '2HbKqm4o0w5wEeEFXm2sD4', '1zCi4cVFqe6ja16MeGZKRN',
#        '439TlnnznSiBbQbgXiBqAd', '3ZFTkvIE7kyPt6Nu3PEa7V',
#        '5i66xrvSh1MjjyDd6zcwgj', '5hlWtrnVUyAze5WkxF9P56',
#        '7iL6o9tox1zgHpKUfh9vuC', '2D1hlMwWWXpkc3CZJ5U351',
#        '6ORqU0bHbVCRjXm9AjyHyZ', '3ZffCQKLFLUvYM59XKLbVm',
#        '5Ozo0lsCaVNJPlKC7RtDnp', '1Je1IMUlBXcx1Fz0WE7oPT',
#        '2X9JCSpysH1GtpcsFS3xDC', '3IeCYkdKI55mNMl2o4vX0k',
#        '3mNecsYFb6LQg7822DPXCP', '4FXdIM78OBdw7KIY2jeM8D',
#        '305WCRhhS10XUcH6AEwZk6', '7kNNylJ1kswWbHeRM6UDuE',
#        '4bHsxqR3GMrXTxEPLuK5ue', '5zA8vzDGqPl2AzZkEYQGKh',
#        '7b4yGtR0rujvLi5EBfKKJ2', '2IgLwduDgZ1sQ7JY4oMvq1',
#        '4oDZ5L8izBals6jKBJDBcX', '4tPL9PeVZY4c0jUPtSD5nx',
#        '5a7NdkF09AfD0H607eiOkX', '7x5xYW5W42OGPAdHUyyguy',
#        '4hJfmMjy3wFIOknfYwhouY', '4sNwdacKyi2S26WrRtNama',
#        '4Y7XAxTANhu3lmnLAzhWJW', '49HtTqTYVUQ5WQoYqz552r',
#        '7DnUGMSrSlAiJNxavwXfye', '12lZTPlXwUtrQuhEty6098',
#        '0Hf4aIJpsN4Os2f0y0VqWl', '2TjnCxxQRYn56Ye8gkUKiW',
#        '1WYokrkFOb9TFVuTrmxTTt', '608xszaAxVh4m7NcKJiAbF',
#        '5lQKRR3MdJLtAwNBiT8Cq0', '2H3ZUSE54pST4ubRd5FzFR',
#        '5mPSyjLatqB00IkPqRlbTE', '3NxAG2ni1lLa8RKL6a0INc',
#        '3aJkV6DUTSCqOwVwaBDG9B', '5XlP5VG4vieZMV4RBCnMnt',
#        '4XZxZXXdpclvC2BkbKtENJ', '3PPSFg8aPyTpAunY5OWgjl',
#        '0Y5iHUJ35MRznhbI8zx1b1', '6AvLZXuzTc2kNs2Bywlswm',
#        '2QvqD5oMhDKHgm5x8pT90s', '42YrWn7KYjhJ2GfjTJ3HSY',
#        '5pLpkaIRobcvPnUmclNv6o', '1FejelrM94Ik1mlI64Ofpb',
#        '4U4FPOKbgrQLKacn9qLcpw', '72fHCHPq9UOkZi5TXN9Y2l',
#        '22HMsy8UyO6gNJTBifeLMC', '4y2m8redOxLjnZywjCmHiQ',
#        '3LV7hmemJUpE8lJPlZk9iH', '1jpXdbxZQ9XXVu69FAUxZk',
#        '52Qu0no0NBho3zyRmjlsHn', '248OFOZef6ShXv6DGgbnxU',
#        '4lcpWCMFXNhvqNIQhB6yDv', '5hTpBe8h35rJ67eAWHQsJx',
#        '0SGkqnVQo9KPytSri1H6cF', '4ImL3v98u2BLkwnyQDjfRm',
#        '2QQuKHdhPoAJchgY0HPw96', '4rqR0yM2k41leqyErhNzTs',
#        '4vojpVoYaj4myAkIcfNKIN', '67T6l4q3zVjC5nZZPXByU8',
#        '4W4GTPUsiYlA46pOyEJq6E', '08pUtyKQKrO8TxoVjakh8f',
#        '4ly1QBXEwYoDmje9rmEgC4', '3fqwjXwUGN6vbzIwvyFMhx',
#        '0p1HtkrNYxv0iDfEKwXSTp', '5g15o2Sm55Hn9ShK5yEXgp',
#        '5HGibWoxnkYSkl6mHmAlOE', '3b7CDTKB0SRTmQ6ytYi5vZ',
#        '0cV4xwUA4ue2deqq4CZFko', '3X6iIrFuQoCshIWBseEKPl',
#        '5FEXPoPnzueFJQCPRIrC3c', '29gsi1zZrZxdStACmTQB0Z',
#        '5sl2735QKaOmL8UL4Q39Ut', '0osPX8TruIebOhKuG6GK8C',
#        '5dKBaysNJtfpyNTRa5lqDb', '5329hKonR0ej5Tq4xmz5gD',
#        '6xe8Sx5h8MYL3ZD5totFZT', '5nHRIKsXDwUpse9gzrAxLR',
#        '5u7JGFtQNT0Zj7TOykBS7s', '4LloVtxNZpeh7q7xdi1DQc',
#        '7cpCU3Denug5NGZsSpQl8v', '6OX0nvTLWngPOKZZB3Usen',
#        '78ofhzJeVCI3wSa09LA6Wp', '5bpdqm75L1udf8tHR5LCfq',
#        '7xMmjUm5gb3q9g4q2bPfxm', '6gTJaPuj8DT8RjuDJyBgzP',
#        '2oCIHudP9wgI3OshvOtNfG', '2A1RPZzGu3qxFL6PiFtyPw',
#        '07Qonra5xGHyjndj0gtOHy', '4PZ4xyWBCCJqAeWI8uSLca',
#        '4XnajLeZt02RnYg4k8kXpm', '1YirIbC1vGEkaQiBrJqY0G',
#        '3VAeTjREoKPY1exOXR4oBm', '4HP24iylfeperCVBfyrp6w',
#        '0q5tedfkNsHbQMyXBTRJ5r', '6XLUlVeCNo4T7Gvkmy6NmC',
#        '6YhZM8eI0DaiNcKgZZBA4M', '0Zh5U48tZNeAzzLTV1CVBE',
#        '4kdfjhj9xNkYU0R8xlDy8k', '12d5QFwzh60IIHlsSnAvps',
#        '79XrkTOfV1AqySNjVlygpW', '5M9kio8FEFiNKyTDGqksy2',
#        '5YUTsFfH1olCp7utJ4ULVT', '5uDASfU19gDxSjW8cnCaBp',
#        '5542ZgcaVlugxNYM4E7wRf', '1rZah1UGXvgiQCqLVlq4hS',
#        '3HVFNvrGnS05DHUzJfOS3n', '1L94M3KIu7QluZe63g64rv',
#        '5Xak5fmy089t0FYmh3VJiY', '6QewNVIDKdSl8Y3ycuHIei',
#        '1AfYo6cKm3yHsJHdmNoGO1', '5NeIONQWJ25uPylJBJiO4c',
#        '2J1t2b8xPBqZzj5znx0C7C', '7hqboBA08HiOvLPd3Ahjod',
#        '4G6E84lvx8jJh4lWv7Fecm', '2fz0ZdAu8kcqdXQ3IuN3YP',
#        '475a6fDXFeJds9swY7P7Rd', '5OTH21tpmWn9YL3XzfB8AX',
#        '7w5cxTEzp1rfV3KCy0Bd5N', '72mvdKU4Lw2737idPLKTjh',
#        '2pmO8V5TEDZqsrcaxSucpj', '2HWWsTZxnLSUdFZ4gjsP5N',
#        '4ECNtOnqzxutZkXP4TE3n3', '7EHmKkyAr6MZv5Y2FdZbXw',
#        '6N1EjQjnvhOjFrF6oUmGPa', '6zeE5tKyr8Nu882DQhhSQI',
#        '3tHPjLBakLS48aumhFpJMt', '4Smc57rqnTjKvz56WJaunv',
#        '0aaOrTcwzvbTni3zUarEaT', '2daZovie6pc2ZK7StayD1K',
#        '1FYtUAJCY4cETakYJaxfZI', '3cbTV3IZZvSBYVcl0xuZbY',
#        '6JEntXLt4z98CcDtIH9sU7', '1V4jC0vJ5525lEF1bFgPX2',
#        '4B4zDmbHdkXZ1wUJv1yKFy', '6cwJUhAR75l6VIGdW8qe96',
#        '3rbNV2GI8Vtd8byhUtXZID', '378iszndTZAR4dH8kwsLC6',
#        '2GiJYvgVaD2HtM8GqD9EgQ', '7yq4Qj7cqayVTp3FF9CWbm',
#        '6hnhksrWAA4OYYpKRh8Oqb', '7lQ8MOhq6IN2w8EYcFNSUk',
#        '4pmU8AtVu9qU40Xd9zjEfA', '6REbwUNlppTfcnV4d4ZoZi',
#        '6nz35DNIzbtj5ztpDEcW1j', '0fgZUSa7D7aVvv3GfO0A1n',
#        '5hgnY0mVcVetszbb85qeDg', '7mitXLIMCflkhZiD34uEQI',
#        '0BruZrBaAqiu08W6nXf34t', '7jFSyIxhRiNB9Ir3foqtYq',
#        '07Tx168RSsUS1HqkDIOZbH', '0g6ISmY4VvTNjMRl2VultZ',
#        '26RZ3DhnVlytdG6N1oxW1E', '6I86RF3odBlcuZA9Vfjzeq',
#        '20k074iuzkjVon8TfsrrCu', '0KqpOdVQoDfeELTKYc97cO',
#        '32lm3769IRfcnrQV11LO4E', '1YwNlWLf8auhazSQUDQLFU',
#        '0Mb20VmqR2lvtgbEermW2v', '4QlzkaRHtU8gAdwqjWmO8n',
#        '4NnWuGQujzWUEg0uZokO5M', '0X5C4WjQNubRysTkHOubz3',
#        '3fyMH1t6UPeR5croea9PrR', '1kEp3Po9RUPm11N5ITOUWx',
#        '4WeD5x4ajB0MmorFmTKomL', '6KqKg8IPuvtDB3PNAvffFf',
#        '3jagJCUbdqhDSPuxP8cAqF', '5nzvgcE7FuekoQTR6WRs18',
#        '3eR23VReFzcdmS7TYCrhCe', '6D0b04NJIKfEMg040WioJQ',
#        '5hYTyyh2odQKphUbMqc5gN', '0Zx8khUcEfCFK2AEoIhC92',
#        '0sO3KbWa7dlv1Olq7v5W3a', '2Jidus904P8XxjE8W56Ezq',
#        '65wWOeVMFKV73ef0x1Q3xA', '0bbrL72MhIRekEi6w3IiKh',
#        '6say8Ws4M1kDqYaUFLXccK', '7H6ev70Weq6DdpZyyTmUXk',
#        '0dQQWHlXvuw4UyHcAvhfhB', '5O06nbk5wDRr1WR3Tyo0Af',
#        '7CEdx5ewzN3SWScQZ1SC2q', '1OjmLuc3Kf34WcEAasCjsO',
#        '2FRnf9qhLbvw8fu4IBXx78', '7BvCDrlYwJ5D9RUqvvs3BT',
#        '3YV3ZrhT6fGPXQieT3Zsrp', '299lFlaAsNQdgbIZNPmIA0',
#        '2qoZNAP3JLyIOtbsPtBjvV', '6l010scCyvcwdQDlxrzClw',
#        '0TbbFwClRBAyURSBynegzo', '6CAgkyKJqbdBgkuggr6XGB',
#        '6bzgDw3ywnsScqlmn4q4l8', '5hC3nG6GuJoTUZixqS0Co4',
#        '6RUKPb4LETWmmr3iAEQktW', '72jbDTw1piOOj770jWNeaG',
#        '7BKLCZ1jbUBVqRi2FVlTVw', '7mldq42yDuxiUNn08nvzHO',
#        '1JdKrFyoU05abww0Zv0ayQ', '4T7KJJg7XCRQdSKGYh5zim',
#        '3D5ORNm9spaTcdRx50ksHx', '3D3lmTEhuWaunO1yxpYPD8',
#        '5B6Z7NwVqA7W3UFiqBdEJC', '4lt3cXW4RkvkHRG4x3K3P4',
#        '4nLaeAathdcgAhhB0h5aWe', '5XltwtaenRRvD9dNj76t5l',
#        '2JCBER0TK8Of3EZ4yB2Y3Q', '0BgbobvykXxEvxo2HhCuvM',
#        '0rpwb2kLgS6KAZsostOj1O', '0kdiUZDcLIFw0Buo9r0Q4z',
#        '3q4uqM3vBuYRD9Oq4tLVJu', '2KpNtGFVWHmkwUW74lhteN',
#        '1RNZLo1oCpUsdZ14BoSv4I', '6grPoklV4nQYAxLsAury9j',
#        '6eSaqh208RQgFsQnU2izZY', '1BltsyC5W3SAABdxyrDXwi',
#        '4kgsK0fftHtg9gZOzkU5T2', '5l3CML2OnzfNs5RfVgbcLt',
#        '3I0FBDc1c1BLNtXWKVjmFg', '6Hr77eZSmaVGgH0vVulMUH',
#        '2714ySK1pbOIGZwABmRyAz', '5RoIXwyTCdyUjpMMkk4uPd',
#        '6ooluO7DiEhI1zmK94nRCM', '2PlP2rRrgSz8lC7MpH3e4e',
#        '0r7dXQYpadl4gYkfgR9ix4', '4o6BgsqLIBViaGVbx5rbRk',
#        '69uxyAqqPIsUyTO8txoP2M', '4r4V1wYecTxSAAXV11cFPD',
#        '2aFiaMXmWsM3Vj72F9ksBl', '20IZ0jYjnFO0NxyiaRsJwb',
#        '0ofbQMrRDsUaVKq2mGLEAb', '2dqLk7ezV15LEJEwUmEbXB',
#        '4WjH9Bzt3kx7z8kl0awxh4', '7HFMdhQYWoedaefIWFin6a',
#        '2FBUoWkIuQXwayw2RNo5l6', '1CvhKmrutTAta5awpJcFDn',
#        '2mqDi8BzmNw54qrVHduyiu', '0PT7nlpo11hYYyfnBgtilT',
#        '2BZv09QyIm1x8TrBOsZpUJ', '4xVWMBB5H7beg8DeHv0bu9',
#        '4536oZLqN3M3QwUWVsyCGH', '0LDFH1WLQ6NPEMH556LUGs',
#        '223BS0F1Svs60EYlbftVut', '4EndPA8b6FDWYp1RgsnLEB',
#        '2ixswrurtpfZHrx406eGgw', '4qqArAiTPueDxIp7cf87h7',
#        '2uPVM8eGYFnAgQCadvReVD', '1UZOjK1BwmwWU14Erba9CZ',
#        '6BqVLNQ0RGU8cytLaHLuo6', '4C1Smq2t3MVOPzsUPWW0oX',
#        '24ZzwmpFaa2dB46pcEon8o', '0dfrww2u9nz7SvQ6doV1LM',
#        '0W6p2Rn4JlqSgGpITeBQ1C', '5g29DkiCtU8WAXa5tOLWtt',
#        '6P316E7tFylzpVrDrXVF9s', '3yPiLKV0BT3FQJD97iacxz',
#        '0PJjfWEnMZZtT1J4yV7dx7', '5q8Dkw2v38Hq9MNsqzLR3E',
#        '6O0BuobS0C8fe9NOPXdyZX', '2d8JP84HNLKhmd6IYOoupQ',
#        '285HeuLxsngjFn4GGegGNm', '08COXcaETx8JB5nsVK2QSu',
#        '5wnfZ7VjDpZNyfJkqc9I1d', '3Sf0jjDIe4xGk4xZ0xbNHY',
#        '5knuzwU65gJK7IF5yJsuaW', '6yIHGmQLJxWAUZ1ZkENemN',
#        '3AEZUABDXNtecAOSC1qTfo', '4rTSPf9iTKfI1Vhzpz7CXb',
#        '5sF7hdYvhrcgNq8NZjfK8L', '2RWs4c3ZJ74WwXlVC3QCQN',
#        '7jqzZyJJLrpkRFYGpkqSK6', '5O6yk6U8L3rTbFsIwuqe8H',
#        '13HVjjWUZFaWilh2QUJKsP', '7fex2V7RzWl9nCKyILjibB',
#        '6UCyheS6PZ3GEn2JE2wfGf', '3Txcx4jhuiTZSvhAL0WaRc',
#        '27mT3JdR3sRJyiMBFHdhB4', '0trHY8tLVJ7Vtkp3DwW6Uo',
#        '57p8CBvPOxrvyCbn6ttl5r', '3m660poUr1chesgkkjQM7P',
#        '0Zbbxnx4SGGHoIow4PpISP', '3B54sVLJ402zGa6Xm4YGNe',
#        '0wvIGFIgbyz4JNwQhZgTv2', '5sFDReWLrZHLFZFjHsjUTS',
#        '6gZVQvQZOFpzIy3HblJ20F', '2JuasWPUodaUxf5nwNpciQ',
#        '7FRfYOql61DGDp9VPPe2qA', '4lxaurdMyGkt1tOrdwRoVO',
#        '1leXuBiWQMgbvOIIedqbLB', '0Zx31zTOm5UHw3NHvLfBif',
#        '1LNpnm5RrX27JJK888Etmb', '5YJZgqCK7sgr07YZJOnfTY',
#        '6qspW4YKycviDFjHBOaqUY', '4buDeg67vos7KP1yHrS9wl',
#        '2Lg4kvhOrPhpGEZmSe7VAN', '06iMqWThw4w8fTFyccvOwr',
#        '6eYYm2xwrvdav2yakF3cqg', '4ACY91spXtmtR8do8iEztJ',
#        '5masKPHeAOVNgxdLebIcK7', '4sPmO7WMQUAf45kwMOtONw',
#        '69bp2EbF7Q2rqc5N3ylezZ', '2SkJKMfjpYsNv0KWOxiegX',
#        '28cFpXHzbTF677wE8eDHE0', '6PZCFT6QljctDqAxuvFhex',
#        '6BubCvEbzzcqyQv6lvGJaA', '7eh1Fov3OjwOx0vqiwnFaK',
#        '0Aj8EagrPfDoOe5OlUdrLC', '7FDi4gAUrMXzafKxEhm9TB',
#        '2XMTqoHHSH0lvuXrvIEdco', '2srMRLGucBrtCubLN70iVv',
#        '46jLy47W8rkf8rEX04gMKB', '5NI4L9cjQ0ptaW9BFyAC9F',
#        '2Im64pIz6m0EJKdUe6eZ8r', '02M6vucOvmRfMxTXDUwRXu',
#        '4dYBLFeLoeZtClQsC6Tuwb', '1IDF4jYiuI17U4BW23EoXV',
#        '2CAK2t1reUgPK6OMgAMURB', '2N9YXTls72jEtq2Pur7vhA',
#        '0qnSjipvB268SHMbNSxZ7y', '0eRzcqXn5dLNa5zOXZySMw',
#        '2a3SHGbb2dPU4TvbfpMWJF', '0PXp9QxBfSKGGpWUNaws2X',
#        '015qd1I4v00JIoK7yOUgKC', '5xl5582IihbEZAnfj0xyso',
#        '1ufxyeu8aGwTLEUGubcoNL', '2I0O4qU0DVUvSCKLW0Bvs6',
#        '5jPgOjFotU05FAgA8Y9IFL', '1z8pHrh6DFDxYrbfVUm6at',
#        '5humEOJehpAwMJEJmb0JJ2', '2uFaJJtFpPDc5Pa95XzTvg',
#        '7h2ZqTG1wdqotTFBpi13f5', '7HKfNGTPIW5BaBidZseHfv',
#        '5NtoPBmhY7WGdpsHmpy9Xh', '7M7e3u2MjbOVTkQMW6XqL6',
#        '1ghaBtBdpuZMg5nV9E2qRU', '0P0vjAUzsleEw8X4aZcOrg',
#        '6QHGyXR0m3PDStlyHN8dYK', '3A7qX2QjDlPnazUsRk5y0M',
#        '4pLwZjInHj3SimIyN9SnOz', '4iLqG9SeJSnt0cSPICSjxv',
#        '7LABrQFfRYcZUqUwng0Heb', '0jr6tT2vc4cIFPHb6wufG3',
#        '3uvypVUsiIr1B0BccIcsEh', '0DQd0tWurMHUAv0cMnDELH',
#        '6sHBvzRsuGunQTfCk18KXi', '4iQLJCvthLGQDXFYkfAXbG',
#        '4NqPAGBUyGelCKnF0N60s2', '4hEl2wrneFEJbJ6SDYWd2f',
#        '3LBCnV4LZ9GNNrga7EH6Gy', '0Ft6hwGWdCdujdK6TOfBV7',
#        '1snNAXmmPXCn0dkF9DaPWw', '068LmtzI6xJJDPfPnMje0U',
#        '3yMQ2HIVpgZHKLLBCBJ52e', '7vcNp4cj4uF4AyX5aKY4Ps',
#        '3z9eNoQmaEX53ZzfKgagaH', '4y1LsJpmMti1PfRQV9AWWe',
#        '7uHO4AmKtyGa5v5fsElGoC', '5ChkMS8OtdzJeqyybCc9R5',
#        '2tUBqZG2AbRi7Q0BIrVrEj', '2FMcDUopGfjBh3xMsrm78S',
#        '2RttW7RAu5nOAfq6YFvApB', '3Lfiu5sZ4M4B6JaKMBc0FU',
#        '4VuS959DSpr82t3qBqCrWG', '0afhq8XCExXpqazXczTSve',
#        '5b88tNINg4Q4nrRbrCXUmg', '32OlwWuMpZ6b0aN2RZOeMS'], dtype=object)

# %%
# storing track uri and artist uri for further use
track_uri=df["track_uri"]
artist_uri=df["artist_uri"]

# %% [markdown]
# ## Data preparation & feature extraction
# Using the Spotify API for Feature Extraction and Saving Results to a CSV File
#
# Initially, we were using SP.track(SPOTIFY WEB API), but we soon realized that it would take a lot of time and require me to work around numerous Api rate constraints, so we switched to SP.tracks and SP.artists. It took far less time because they allow lists with a limit of 50 URIs and handle them in a single request.
# https://spotipy.readthedocs.io/en/latest/

# %%
f = open('audio_features.csv','a')

for i in tqdm(range(0, len(track_uri), 100)):
    try:
        track_feature = sp.audio_features(track_uri[i:i+100])
        track_df = pd.DataFrame(track_feature)
        track_csv_data = track_df.to_csv(header=False,index=False)
        f.write(track_csv_data)
    except Exception as error:
        time.sleep(3)
        continue

f.close()
# Out:
# 100%|███████████████████████████████████████| 2810/2810 [08:39<00:00,  5.41it/s]

# %%
audio_features=pd.read_csv("audio_features.csv")
audio_features
# Out:
#          0.89  0.672   7  -5.532  1  0.0621   0.707  0.000604   0.177   0.598  \
# 0       0.883  0.817   0  -5.414  1  0.2350  0.6010  0.004490  0.1100  0.5950
# 1       0.586  0.626   1  -8.448  1  0.0356  0.0874  0.000380  0.1130  0.0519
# 2       0.654  0.304   6  -9.067  0  0.0358  0.6470  0.000072  0.1470  0.1020
# 3       0.690  0.578   6  -7.436  1  0.0929  0.1670  0.000000  0.3050  0.4160
# 4       0.500  0.726   5  -4.124  1  0.0643  0.0362  0.000000  0.4410  0.3970
# ...       ...    ...  ..     ... ..     ...     ...       ...     ...     ...
# 347037  0.741  0.841   2  -6.398  0  0.2160  0.0702  0.000000  0.1460  0.7300
# 347038  0.767  0.856   7  -2.715  1  0.0410  0.0303  0.000002  0.3600  0.7470
# 347039  0.496  0.372   4  -5.841  1  0.0662  0.6820  0.000000  0.1550  0.5580
# 347040  0.707  0.707  11  -6.161  0  0.0375  0.0306  0.000000  0.1270  0.2310
# 347041  0.739  0.792  11  -4.256  0  0.0418  0.0910  0.000000  0.0516  0.5470
#
#         126.036  audio_features  66U0ASk1VHZsqIkpMjKX3B  \
# 0       128.078  audio_features  5MhsZlmKJG6X5kTHkdwC4B
# 1        94.965  audio_features  0GZoB8h0kqXn7XFm4Sj06k
# 2       113.992  audio_features  35kahykNu00FPysz3C2euR
# 3        99.961  audio_features  3G6hD9B2ZHOsgf4WfNu7X1
# 4       125.904  audio_features  6WQLkih8nE0JdUCEyLaGnQ
# ...         ...             ...                     ...
# 347037   94.846  audio_features  38griAVM808crjbFp9gcPD
# 347038   91.535  audio_features  1JClFT74TYSXlzpagbmj0S
# 347039   87.011  audio_features  4InLm5a9Qtkru6YxEjM4Qc
# 347040  104.039  audio_features  4hdog9vyyqG9pcppG2Izek
# 347041  104.016  audio_features  0NiXXAI876aGImAd6rTj8w
#
#         spotify:track:66U0ASk1VHZsqIkpMjKX3B  \
# 0       spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 1       spotify:track:0GZoB8h0kqXn7XFm4Sj06k
# 2       spotify:track:35kahykNu00FPysz3C2euR
# 3       spotify:track:3G6hD9B2ZHOsgf4WfNu7X1
# 4       spotify:track:6WQLkih8nE0JdUCEyLaGnQ
# ...                                      ...
# 347037  spotify:track:38griAVM808crjbFp9gcPD
# 347038  spotify:track:1JClFT74TYSXlzpagbmj0S
# 347039  spotify:track:4InLm5a9Qtkru6YxEjM4Qc
# 347040  spotify:track:4hdog9vyyqG9pcppG2Izek
# 347041  spotify:track:0NiXXAI876aGImAd6rTj8w
#
#        https://api.spotify.com/v1/tracks/66U0ASk1VHZsqIkpMjKX3B  \
# 0       https://api.spotify.com/v1/tracks/5MhsZlmKJG6X...
# 1       https://api.spotify.com/v1/tracks/0GZoB8h0kqXn...
# 2       https://api.spotify.com/v1/tracks/35kahykNu00F...
# 3       https://api.spotify.com/v1/tracks/3G6hD9B2ZHOs...
# 4       https://api.spotify.com/v1/tracks/6WQLkih8nE0J...
# ...                                                   ...
# 347037  https://api.spotify.com/v1/tracks/38griAVM808c...
# 347038  https://api.spotify.com/v1/tracks/1JClFT74TYSX...
# 347039  https://api.spotify.com/v1/tracks/4InLm5a9Qtkr...
# 347040  https://api.spotify.com/v1/tracks/4hdog9vyyqG9...
# 347041  https://api.spotify.com/v1/tracks/0NiXXAI876aG...
#
#        https://api.spotify.com/v1/audio-analysis/66U0ASk1VHZsqIkpMjKX3B  \
# 0       https://api.spotify.com/v1/audio-analysis/5Mhs...
# 1       https://api.spotify.com/v1/audio-analysis/0GZo...
# 2       https://api.spotify.com/v1/audio-analysis/35ka...
# 3       https://api.spotify.com/v1/audio-analysis/3G6h...
# 4       https://api.spotify.com/v1/audio-analysis/6WQL...
# ...                                                   ...
# 347037  https://api.spotify.com/v1/audio-analysis/38gr...
# 347038  https://api.spotify.com/v1/audio-analysis/1JCl...
# 347039  https://api.spotify.com/v1/audio-analysis/4InL...
# 347040  https://api.spotify.com/v1/audio-analysis/4hdo...
# 347041  https://api.spotify.com/v1/audio-analysis/0NiX...
#
#         163810  4
# 0       166849  4
# 1       232507  4
# 2       216600  4
# 3       193059  4
# 4       210013  4
# ...        ... ..
# 347037  339573  4
# 347038  285027  4
# 347039  279322  4
# 347040  223296  4
# 347041  181615  4
#
# [347042 rows x 18 columns]

# %%
f = open('artist_features.csv','a')

for i in tqdm(range(0, len(artist_uri), 50)):
    try:
        artist_features = sp.artists(artist_uri[i:i+50])
        #track_pop = sp.tracks(t_uri[i:i+50])
        
        for x in range(50):
            artist_df = pd.DataFrame([artist_uri[i+x]])
            artist_popularity = artist_features['artists'][x]["popularity"]
            artist_genres = artist_features['artists'][x]["genres"]
            artist_df["artist_pop"] = artist_popularity
            if artist_genres: 
                artist_df["genres"] = " ".join([re.sub(' ', '_', i) for i in artist_genres])
            else:
                artist_df["genres"] = "unknown"
            
            #artist_df["track_pop"] =  track_pop["popularity"]
            #print(artist_df["track_pop"] )
            csv_data = artist_df.to_csv(header=False,index=False)
            f.write(csv_data)
    except Exception as error:
        time.sleep(3)
        continue
        
f.close()
# Out:
# 100%|███████████████████████████████████████| 5620/5620 [14:12<00:00,  6.59it/s]

# %%
artist_features = pd.read_csv("artist_features.csv")
artist_features
# Out:
#         spotify:artist:5vCOdeiQt9LyzdI87kt5Sh  60  \
# 0       spotify:artist:163tK9Wjr9P9DmM0AVK7lm  75
# 1       spotify:artist:4AVFqumd2ogHFlRbKIjp1t  75
# 2       spotify:artist:3AQRLZ9PuTAozP28Skbq8V  73
# 3       spotify:artist:4UXqAaa6dQYAk18Lv7PEgX  77
# 4       spotify:artist:0MlOPi3zIDMVrfA9R04Fe3  65
# ...                                       ...  ..
# 295092  spotify:artist:6nnspeopmJAG07xOxHmqTu  61
# 295093  spotify:artist:1ZwdS5xdxEREPySFridCfh  79
# 295094  spotify:artist:2Y9lO01ABSO8OkBU8FI1mp  22
# 295095  spotify:artist:2cFrymmkijnjDg9SS92EPM  78
# 295096  spotify:artist:1HBjj22wzbscIZ9sEb5dyf  73
#
#                                               swedish_pop
# 0                         art_pop metropopolis nz_pop pop
# 1       dance_pop edm electro_house pop pop_dance trop...
# 2                     celtic_rock neo_mellow pop pop_rock
# 3                                         emo modern_rock
# 4                    indie_poptimism modern_rock pop_rock
# ...                                                   ...
# 295092                salsa salsa_puertorriquena tropical
# 295093     g_funk gangster_rap hip_hop rap west_coast_rap
# 295094                                  minneapolis_indie
# 295095                                        pop pop_rap
# 295096  dance_pop edm pop pop_dance tropical_house uk_...
#
# [295097 rows x 3 columns]

# %%
artist_uri = df["artist_uri"]

# %%
artist_uri
# Out:
# 0         spotify:artist:5vCOdeiQt9LyzdI87kt5Sh
# 1         spotify:artist:5vCOdeiQt9LyzdI87kt5Sh
# 2         spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# 3         spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# 4         spotify:artist:163tK9Wjr9P9DmM0AVK7lm
#                           ...
# 280995    spotify:artist:6nnspeopmJAG07xOxHmqTu
# 280996    spotify:artist:1ZwdS5xdxEREPySFridCfh
# 280997    spotify:artist:2Y9lO01ABSO8OkBU8FI1mp
# 280998    spotify:artist:2cFrymmkijnjDg9SS92EPM
# 280999    spotify:artist:1HBjj22wzbscIZ9sEb5dyf
# Name: artist_uri, Length: 281000, dtype: object

# %%
df["track_uri"]
# Out:
# 0         66U0ASk1VHZsqIkpMjKX3B
# 1         5MhsZlmKJG6X5kTHkdwC4B
# 2         0GZoB8h0kqXn7XFm4Sj06k
# 3         35kahykNu00FPysz3C2euR
# 4         3G6hD9B2ZHOsgf4WfNu7X1
#                    ...
# 280995    38griAVM808crjbFp9gcPD
# 280996    1JClFT74TYSXlzpagbmj0S
# 280997    4InLm5a9Qtkru6YxEjM4Qc
# 280998    4hdog9vyyqG9pcppG2Izek
# 280999    0NiXXAI876aGImAd6rTj8w
# Name: track_uri, Length: 281000, dtype: object

# %%
f = open('track_features.csv','a')

for i in tqdm(range(0, len(track_uri), 50)):
    try:
        track_features = sp.tracks(track_uri[i:i+50])
        for x in range(50):
            track_popularity = pd.DataFrame([track_uri[i+x]])
            track_popularity['release_date']=track_features['tracks'][x]['album']['release_date']
            track_popularity['pop'] = track_features['tracks'][x]["popularity"]
            csv_data = track_popularity.to_csv(header=False,index=False)
            f.write(csv_data)
    except Exception as error:
        time.sleep(3)
        continue
        
f.close()
# Out:
# 100%|███████████████████████████████████████| 5620/5620 [30:02<00:00,  3.12it/s]

# %%
track_features = pd.read_csv("track_features.csv")
track_features
# Out:
#         66U0ASk1VHZsqIkpMjKX3B  2016-02-26  59
# 0       5MhsZlmKJG6X5kTHkdwC4B  2014-08-08  72
# 1       0GZoB8h0kqXn7XFm4Sj06k  2014-09-30   0
# 2       35kahykNu00FPysz3C2euR  2013-09-27  58
# 3       3G6hD9B2ZHOsgf4WfNu7X1  2013-09-27  76
# 4       6WQLkih8nE0JdUCEyLaGnQ  2015-05-22   0
# ...                        ...         ...  ..
# 280717  38griAVM808crjbFp9gcPD        2003  14
# 280718  1JClFT74TYSXlzpagbmj0S  1998-01-01  64
# 280719  4InLm5a9Qtkru6YxEjM4Qc  2015-03-10  32
# 280720  4hdog9vyyqG9pcppG2Izek  2015-02-14  53
# 280721  0NiXXAI876aGImAd6rTj8w  2017-07-14  50
#
# [280722 rows x 3 columns]
